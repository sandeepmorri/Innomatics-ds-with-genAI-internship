# %%
#1.hello world
if __name__ == '__main__':
    print("Hello, World!")
# Out:
# Hello, World!

# %%
#2.if else program
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    if n&1:
        print("Weird")
    elif not(n&1) and (n<=5 and n>=2):
        print("Not Weird")
    elif not(n&1) and (n<=20 and n>=6):
        print("Weird")
    elif not(n&1) and (n>20):
        print("Not Weird")
# Out:
# 6
# Weird

# %%
#3.arithmetic operators
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)
# Out:
# 2
# 5
# 7
# -3
# 10

# %%
#4.division
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)
# Out:
# 3
# 4
# 0
# 0.75

# %%
#5.loops
if __name__ == '__main__':
    n = int(input())
    for i in range(n):
        print(i**2)
# Out:
# 6
# 0
# 1
# 4
# 9
# 16
# 25

# %%
#6.function concept
def is_leap(year):
    leap = False
    if year%4==0 or year%400==0:
        leap=True
    if year%100==0 and not year%400==0:
        return False
    # Write your logic here

    return leap

year = int(input())
# Out:
# 1900

# %%
#7.print
if __name__ == '__main__':
    n = int(input())
    for i in range(1,n+1):
        print(i,end="")
# Out:
# 6
# 123456
